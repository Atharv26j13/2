# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharv26j13/2/blob/main/21d_22_5_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# gen1_pokemon.py
# Format:
# name, hp (base HP), damage (base Attack), weakness (Gen 1 type weaknesses), type

gen1_pokemon = [
    {"name":"Bulbasaur","hp":45,"damage":49,"weakness":["Fire","Ice","Flying","Psychic"],"type":["Grass","Poison"]},
    {"name":"Ivysaur","hp":60,"damage":62,"weakness":["Fire","Ice","Flying","Psychic"],"type":["Grass","Poison"]},
    {"name":"Venusaur","hp":80,"damage":82,"weakness":["Fire","Ice","Flying","Psychic"],"type":["Grass","Poison"]},
    {"name":"Charmander","hp":39,"damage":52,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Charmeleon","hp":58,"damage":64,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Charizard","hp":78,"damage":84,"weakness":["Water","Electric","Rock"],"type":["Fire","Flying"]},
    {"name":"Squirtle","hp":44,"damage":48,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Wartortle","hp":59,"damage":63,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Blastoise","hp":79,"damage":83,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Caterpie","hp":45,"damage":30,"weakness":["Fire","Flying","Rock"],"type":["Bug"]},
    {"name":"Metapod","hp":50,"damage":20,"weakness":["Fire","Flying","Rock"],"type":["Bug"]},
    {"name":"Butterfree","hp":60,"damage":45,"weakness":["Fire","Electric","Ice","Flying","Rock"],"type":["Bug","Flying"]},
    {"name":"Weedle","hp":40,"damage":35,"weakness":["Fire","Flying","Psychic","Rock"],"type":["Bug","Poison"]},
    {"name":"Kakuna","hp":45,"damage":25,"weakness":["Fire","Flying","Psychic","Rock"],"type":["Bug","Poison"]},
    {"name":"Beedrill","hp":65,"damage":80,"weakness":["Fire","Flying","Psychic","Rock"],"type":["Bug","Poison"]},
    {"name":"Pidgey","hp":40,"damage":45,"weakness":["Electric","Ice","Rock"],"type":["Normal","Flying"]},
    {"name":"Pidgeotto","hp":63,"damage":60,"weakness":["Electric","Ice","Rock"],"type":["Normal","Flying"]},
    {"name":"Pidgeot","hp":83,"damage":80,"weakness":["Electric","Ice","Rock"],"type":["Normal","Flying"]},
    {"name":"Rattata","hp":30,"damage":56,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Raticate","hp":55,"damage":81,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Spearow","hp":40,"damage":60,"weakness":["Electric","Ice","Rock"],"type":["Normal","Flying"]},
    {"name":"Fearow","hp":65,"damage":90,"weakness":["Electric","Ice","Rock"],"type":["Normal","Flying"]},
    {"name":"Ekans","hp":35,"damage":60,"weakness":["Ground","Psychic"],"type":["Poison"]},
    {"name":"Arbok","hp":60,"damage":85,"weakness":["Ground","Psychic"],"type":["Poison"]},
    {"name":"Pikachu","hp":35,"damage":55,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Raichu","hp":60,"damage":90,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Sandshrew","hp":50,"damage":75,"weakness":["Water","Grass","Ice"],"type":["Ground"]},
    {"name":"Sandslash","hp":75,"damage":100,"weakness":["Water","Grass","Ice"],"type":["Ground"]},
    {"name":"Nidoran♀","hp":55,"damage":47,"weakness":["Ground","Psychic"],"type":["Poison"]},
    {"name":"Nidorina","hp":70,"damage":62,"weakness":["Ground","Psychic"],"type":["Poison"]},
    {"name":"Nidoqueen","hp":90,"damage":82,"weakness":["Water","Grass","Ice","Ground","Psychic"],"type":["Poison","Ground"]},
    {"name":"Nidoran♂","hp":46,"damage":57,"weakness":["Ground","Psychic"],"type":["Poison"]},
    {"name":"Nidorino","hp":61,"damage":72,"weakness":["Ground","Psychic"],"type":["Poison"]},
    {"name":"Nidoking","hp":81,"damage":92,"weakness":["Water","Grass","Ice","Ground","Psychic"],"type":["Poison","Ground"]},
    {"name":"Clefairy","hp":70,"damage":45,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Clefable","hp":95,"damage":70,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Vulpix","hp":38,"damage":41,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Ninetales","hp":73,"damage":76,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Jigglypuff","hp":115,"damage":45,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Wigglytuff","hp":140,"damage":70,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Zubat","hp":40,"damage":45,"weakness":["Electric","Ice","Psychic","Rock"],"type":["Poison","Flying"]},
    {"name":"Golbat","hp":75,"damage":80,"weakness":["Electric","Ice","Psychic","Rock"],"type":["Poison","Flying"]},
    {"name":"Oddish","hp":45,"damage":50,"weakness":["Fire","Ice","Flying","Psychic"],"type":["Grass","Poison"]},
    {"name":"Gloom","hp":60,"damage":65,"weakness":["Fire","Ice","Flying","Psychic"],"type":["Grass","Poison"]},
    {"name":"Vileplume","hp":75,"damage":80,"weakness":["Fire","Ice","Flying","Psychic"],"type":["Grass","Poison"]},
    {"name":"Paras","hp":35,"damage":70,"weakness":["Fire","Ice","Flying","Poison","Rock","Bug"],"type":["Bug","Grass"]},
    {"name":"Parasect","hp":60,"damage":95,"weakness":["Fire","Ice","Flying","Poison","Rock","Bug"],"type":["Bug","Grass"]},
    {"name":"Venonat","hp":60,"damage":55,"weakness":["Fire","Flying","Psychic","Rock"],"type":["Bug","Poison"]},
    {"name":"Venomoth","hp":70,"damage":65,"weakness":["Fire","Flying","Psychic","Rock"],"type":["Bug","Poison"]},
    {"name":"Diglett","hp":10,"damage":55,"weakness":["Water","Grass","Ice"],"type":["Ground"]},
    {"name":"Dugtrio","hp":35,"damage":80,"weakness":["Water","Grass","Ice"],"type":["Ground"]},
    {"name":"Meowth","hp":40,"damage":45,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Persian","hp":65,"damage":70,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Psyduck","hp":50,"damage":52,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Golduck","hp":80,"damage":82,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Mankey","hp":40,"damage":80,"weakness":["Flying","Psychic"],"type":["Fighting"]},
    {"name":"Primeape","hp":65,"damage":105,"weakness":["Flying","Psychic"],"type":["Fighting"]},
    {"name":"Growlithe","hp":55,"damage":70,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Arcanine","hp":90,"damage":110,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Poliwag","hp":40,"damage":50,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Poliwhirl","hp":65,"damage":65,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Poliwrath","hp":90,"damage":85,"weakness":["Electric","Grass","Flying","Psychic"],"type":["Water","Fighting"]},
    {"name":"Abra","hp":25,"damage":20,"weakness":["Bug","Ghost"],"type":["Psychic"]},
    {"name":"Kadabra","hp":40,"damage":35,"weakness":["Bug","Ghost"],"type":["Psychic"]},
    {"name":"Alakazam","hp":55,"damage":50,"weakness":["Bug","Ghost"],"type":["Psychic"]},
    {"name":"Machop","hp":70,"damage":80,"weakness":["Flying","Psychic"],"type":["Fighting"]},
    {"name":"Machoke","hp":80,"damage":100,"weakness":["Flying","Psychic"],"type":["Fighting"]},
    {"name":"Machamp","hp":90,"damage":130,"weakness":["Flying","Psychic"],"type":["Fighting"]},
    {"name":"Bellsprout","hp":50,"damage":75,"weakness":["Fire","Ice","Flying","Psychic"],"type":["Grass","Poison"]},
    {"name":"Weepinbell","hp":65,"damage":90,"weakness":["Fire","Ice","Flying","Psychic"],"type":["Grass","Poison"]},
    {"name":"Victreebel","hp":80,"damage":105,"weakness":["Fire","Ice","Flying","Psychic"],"type":["Grass","Poison"]},
    {"name":"Tentacool","hp":40,"damage":40,"weakness":["Electric","Ground","Psychic"],"type":["Water","Poison"]},
    {"name":"Tentacruel","hp":80,"damage":70,"weakness":["Electric","Ground","Psychic"],"type":["Water","Poison"]},
    {"name":"Geodude","hp":40,"damage":80,"weakness":["Water","Grass","Ice","Ground","Fighting"],"type":["Rock","Ground"]},
    {"name":"Graveler","hp":55,"damage":95,"weakness":["Water","Grass","Ice","Ground","Fighting"],"type":["Rock","Ground"]},
    {"name":"Golem","hp":80,"damage":110,"weakness":["Water","Grass","Ice","Ground","Fighting"],"type":["Rock","Ground"]},
    {"name":"Ponyta","hp":50,"damage":85,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Rapidash","hp":65,"damage":100,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Slowpoke","hp":90,"damage":65,"weakness":["Electric","Grass","Bug","Ghost"],"type":["Water","Psychic"]},
    {"name":"Slowbro","hp":95,"damage":75,"weakness":["Electric","Grass","Bug","Ghost"],"type":["Water","Psychic"]},
    {"name":"Magnemite","hp":25,"damage":35,"weakness":["Fire","Water","Fighting","Ground"],"type":["Electric"]},
    {"name":"Magneton","hp":50,"damage":60,"weakness":["Fire","Water","Fighting","Ground"],"type":["Electric"]},
    {"name":"Farfetch'd","hp":52,"damage":65,"weakness":["Electric","Ice","Rock"],"type":["Normal","Flying"]},
    {"name":"Doduo","hp":35,"damage":85,"weakness":["Electric","Ice","Rock"],"type":["Normal","Flying"]},
    {"name":"Dodrio","hp":60,"damage":110,"weakness":["Electric","Ice","Rock"],"type":["Normal","Flying"]},
    {"name":"Seel","hp":65,"damage":45,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Dewgong","hp":90,"damage":70,"weakness":["Electric","Grass","Fighting","Rock"],"type":["Water","Ice"]},
    {"name":"Grimer","hp":80,"damage":80,"weakness":["Ground","Psychic"],"type":["Poison"]},
    {"name":"Muk","hp":105,"damage":105,"weakness":["Ground","Psychic"],"type":["Poison"]},
    {"name":"Shellder","hp":30,"damage":65,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Cloyster","hp":50,"damage":95,"weakness":["Electric","Grass","Fighting","Rock"],"type":["Water","Ice"]},
    {"name":"Gastly","hp":30,"damage":35,"weakness":["Ground","Psychic","Ghost"],"type":["Ghost","Poison"]},
    {"name":"Haunter","hp":45,"damage":50,"weakness":["Ground","Psychic","Ghost"],"type":["Ghost","Poison"]},
    {"name":"Gengar","hp":60,"damage":65,"weakness":["Ground","Psychic","Ghost"],"type":["Ghost","Poison"]},
    {"name":"Onix","hp":35,"damage":45,"weakness":["Water","Grass","Ice","Ground","Fighting"],"type":["Rock","Ground"]},
    {"name":"Drowzee","hp":60,"damage":48,"weakness":["Bug","Ghost"],"type":["Psychic"]},
    {"name":"Hypno","hp":85,"damage":73,"weakness":["Bug","Ghost"],"type":["Psychic"]},
    {"name":"Krabby","hp":30,"damage":105,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Kingler","hp":55,"damage":130,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Voltorb","hp":40,"damage":30,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Electrode","hp":60,"damage":50,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Exeggcute","hp":60,"damage":40,"weakness":["Fire","Ice","Flying","Bug","Ghost"],"type":["Grass","Psychic"]},
    {"name":"Exeggutor","hp":95,"damage":95,"weakness":["Fire","Ice","Flying","Bug","Ghost"],"type":["Grass","Psychic"]},
    {"name":"Cubone","hp":50,"damage":50,"weakness":["Water","Grass","Ice"],"type":["Ground"]},
    {"name":"Marowak","hp":60,"damage":80,"weakness":["Water","Grass","Ice"],"type":["Ground"]},
    {"name":"Hitmonlee","hp":50,"damage":120,"weakness":["Flying","Psychic"],"type":["Fighting"]},
    {"name":"Hitmonchan","hp":50,"damage":105,"weakness":["Flying","Psychic"],"type":["Fighting"]},
    {"name":"Lickitung","hp":90,"damage":55,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Koffing","hp":40,"damage":65,"weakness":["Ground","Psychic"],"type":["Poison"]},
    {"name":"Weezing","hp":65,"damage":90,"weakness":["Ground","Psychic"],"type":["Poison"]},
    {"name":"Rhyhorn","hp":80,"damage":85,"weakness":["Water","Grass","Ice","Ground","Fighting"],"type":["Ground","Rock"]},
    {"name":"Rhydon","hp":105,"damage":130,"weakness":["Water","Grass","Ice","Ground","Fighting"],"type":["Ground","Rock"]},
    {"name":"Chansey","hp":250,"damage":5,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Tangela","hp":65,"damage":55,"weakness":["Fire","Ice","Flying","Bug","Poison"],"type":["Grass"]},
    {"name":"Kangaskhan","hp":105,"damage":95,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Horsea","hp":30,"damage":40,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Seadra","hp":55,"damage":65,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Goldeen","hp":45,"damage":67,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Seaking","hp":80,"damage":92,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Staryu","hp":30,"damage":45,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Starmie","hp":60,"damage":75,"weakness":["Electric","Grass","Bug","Ghost"],"type":["Water","Psychic"]},
    {"name":"Mr. Mime","hp":40,"damage":45,"weakness":["Bug","Ghost"],"type":["Psychic"]},
    {"name":"Scyther","hp":70,"damage":110,"weakness":["Fire","Electric","Ice","Flying","Rock"],"type":["Bug","Flying"]},
    {"name":"Jynx","hp":65,"damage":50,"weakness":["Fire","Bug","Rock","Ghost"],"type":["Ice","Psychic"]},
    {"name":"Electabuzz","hp":65,"damage":83,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Magmar","hp":65,"damage":95,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Pinsir","hp":65,"damage":125,"weakness":["Fire","Flying","Rock"],"type":["Bug"]},
    {"name":"Tauros","hp":75,"damage":100,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Magikarp","hp":20,"damage":10,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Gyarados","hp":95,"damage":125,"weakness":["Electric","Rock"],"type":["Water","Flying"]},
    {"name":"Lapras","hp":130,"damage":85,"weakness":["Electric","Grass","Fighting","Rock"],"type":["Water","Ice"]},
    {"name":"Ditto","hp":48,"damage":48,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Eevee","hp":55,"damage":55,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Vaporeon","hp":130,"damage":65,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Jolteon","hp":65,"damage":65,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Flareon","hp":65,"damage":130,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Porygon","hp":65,"damage":60,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Omanyte","hp":35,"damage":40,"weakness":["Electric","Grass","Fighting","Ground"],"type":["Rock","Water"]},
    {"name":"Omastar","hp":70,"damage":60,"weakness":["Electric","Grass","Fighting","Ground"],"type":["Rock","Water"]},
    {"name":"Kabuto","hp":30,"damage":80,"weakness":["Electric","Grass","Fighting","Ground"],"type":["Rock","Water"]},
    {"name":"Kabutops","hp":60,"damage":115,"weakness":["Electric","Grass","Fighting","Ground"],"type":["Rock","Water"]},
    {"name":"Aerodactyl","hp":80,"damage":105,"weakness":["Water","Electric","Ice","Rock"],"type":["Rock","Flying"]},
    {"name":"Snorlax","hp":160,"damage":110,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Articuno","hp":90,"damage":85,"weakness":["Fire","Electric","Rock"],"type":["Ice","Flying"]},
    {"name":"Zapdos","hp":90,"damage":90,"weakness":["Ice","Rock"],"type":["Electric","Flying"]},
    {"name":"Moltres","hp":90,"damage":100,"weakness":["Water","Electric","Rock"],"type":["Fire","Flying"]},
    {"name":"Dratini","hp":41,"damage":64,"weakness":["Ice","Dragon"],"type":["Dragon"]},
    {"name":"Dragonair","hp":61,"damage":84,"weakness":["Ice","Dragon"],"type":["Dragon"]},
    {"name":"Dragonite","hp":91,"damage":134,"weakness":["Ice","Rock","Dragon"],"type":["Dragon","Flying"]},
    {"name":"Mewtwo","hp":106,"damage":110,"weakness":["Bug","Ghost"],"type":["Psychic"]},
    {"name":"Mew","hp":100,"damage":100,"weakness":["Bug","Ghost"],"type":["Psychic"]},
    {"name":"Articuno","hp":90,"damage":85,"weakness":["Fire","Electric","Rock"],"type":["Ice","Flying"]},
    {"name":"Zapdos","hp":90,"damage":90,"weakness":["Ice","Rock"],"type":["Electric","Flying"]},
    {"name":"Moltres","hp":90,"damage":100,"weakness":["Water","Electric","Rock"],"type":["Fire","Flying"]},
    {"name":"Dratini","hp":41,"damage":64,"weakness":["Ice","Dragon"],"type":["Dragon"]},
    {"name":"Dragonair","hp":61,"damage":84,"weakness":["Ice","Dragon"],"type":["Dragon"]},
    {"name":"Dragonite","hp":91,"damage":134,"weakness":["Ice","Rock","Dragon"],"type":["Dragon","Flying"]},
    {"name":"Mewtwo","hp":106,"damage":110,"weakness":["Bug","Ghost"],"type":["Psychic"]},
    {"name":"Mew","hp":100,"damage":100,"weakness":["Bug","Ghost"],"type":["Psychic"]}
]

gen2_pokemon = [
    {"name":"Chikorita","hp":45,"damage":49,"weakness":["Fire","Ice","Flying","Bug","Poison"],"type":["Grass"]},
    {"name":"Bayleef","hp":60,"damage":62,"weakness":["Fire","Ice","Flying","Bug","Poison"],"type":["Grass"]},
    {"name":"Meganium","hp":80,"damage":82,"weakness":["Fire","Ice","Flying","Bug","Poison"],"type":["Grass"]},
    {"name":"Cyndaquil","hp":39,"damage":52,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Quilava","hp":58,"damage":64,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Typhlosion","hp":78,"damage":84,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Totodile","hp":50,"damage":65,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Croconaw","hp":65,"damage":80,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Feraligatr","hp":85,"damage":105,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Sentret","hp":35,"damage":46,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Furret","hp":85,"damage":76,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Hoothoot","hp":60,"damage":30,"weakness":["Electric","Ice","Rock"],"type":["Normal","Flying"]},
    {"name":"Noctowl","hp":100,"damage":50,"weakness":["Electric","Ice","Rock"],"type":["Normal","Flying"]},
    {"name":"Ledyba","hp":40,"damage":20,"weakness":["Fire","Electric","Ice","Flying","Rock"],"type":["Bug","Flying"]},
    {"name":"Ledian","hp":55,"damage":35,"weakness":["Fire","Electric","Ice","Flying","Rock"],"type":["Bug","Flying"]},
    {"name":"Spinarak","hp":40,"damage":60,"weakness":["Fire","Flying","Psychic","Rock"],"type":["Bug","Poison"]},
    {"name":"Ariados","hp":70,"damage":90,"weakness":["Fire","Flying","Psychic","Rock"],"type":["Bug","Poison"]},
    {"name":"Crobat","hp":85,"damage":90,"weakness":["Electric","Ice","Psychic","Rock"],"type":["Poison","Flying"]},
    {"name":"Chinchou","hp":75,"damage":38,"weakness":["Grass","Ground"],"type":["Water","Electric"]},
    {"name":"Lanturn","hp":125,"damage":58,"weakness":["Grass","Ground"],"type":["Water","Electric"]},
    {"name":"Pichu","hp":20,"damage":40,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Cleffa","hp":50,"damage":25,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Igglybuff","hp":90,"damage":30,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Togepi","hp":35,"damage":20,"weakness":["Poison","Steel"],"type":["Fairy"]},
    {"name":"Togetic","hp":55,"damage":40,"weakness":["Electric","Ice","Poison","Rock","Steel"],"type":["Fairy","Flying"]},
    {"name":"Natu","hp":40,"damage":50,"weakness":["Electric","Ice","Rock","Ghost","Dark"],"type":["Psychic","Flying"]},
    {"name":"Xatu","hp":65,"damage":75,"weakness":["Electric","Ice","Rock","Ghost","Dark"],"type":["Psychic","Flying"]},
    {"name":"Mareep","hp":55,"damage":40,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Flaaffy","hp":70,"damage":55,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Ampharos","hp":90,"damage":75,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Bellossom","hp":75,"damage":80,"weakness":["Fire","Ice","Flying","Bug","Poison"],"type":["Grass"]},
    {"name":"Marill","hp":70,"damage":20,"weakness":["Electric","Grass","Poison"],"type":["Water","Fairy"]},
    {"name":"Azumarill","hp":100,"damage":50,"weakness":["Electric","Grass","Poison"],"type":["Water","Fairy"]},
    {"name":"Sudowoodo","hp":70,"damage":100,"weakness":["Water","Grass","Fighting","Ground","Steel"],"type":["Rock"]},
    {"name":"Politoed","hp":90,"damage":75,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Hoppip","hp":35,"damage":35,"weakness":["Fire","Ice","Poison","Flying","Rock"],"type":["Grass","Flying"]},
    {"name":"Skiploom","hp":55,"damage":45,"weakness":["Fire","Ice","Poison","Flying","Rock"],"type":["Grass","Flying"]},
    {"name":"Jumpluff","hp":75,"damage":55,"weakness":["Fire","Ice","Poison","Flying","Rock"],"type":["Grass","Flying"]},
    {"name":"Aipom","hp":55,"damage":70,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Sunkern","hp":30,"damage":30,"weakness":["Fire","Ice","Flying","Bug","Poison"],"type":["Grass"]},
    {"name":"Sunflora","hp":75,"damage":75,"weakness":["Fire","Ice","Flying","Bug","Poison"],"type":["Grass"]},
    {"name":"Yanma","hp":65,"damage":65,"weakness":["Fire","Electric","Ice","Flying","Rock"],"type":["Bug","Flying"]},
    {"name":"Wooper","hp":55,"damage":45,"weakness":["Grass"],"type":["Water","Ground"]},
    {"name":"Quagsire","hp":95,"damage":85,"weakness":["Grass"],"type":["Water","Ground"]},
    {"name":"Espeon","hp":65,"damage":65,"weakness":["Bug","Ghost","Dark"],"type":["Psychic"]},
    {"name":"Umbreon","hp":95,"damage":65,"weakness":["Fighting","Bug","Fairy"],"type":["Dark"]},
    {"name":"Murkrow","hp":60,"damage":85,"weakness":["Electric","Ice","Rock","Fairy"],"type":["Dark","Flying"]},
    {"name":"Slowking","hp":95,"damage":75,"weakness":["Electric","Grass","Bug","Ghost","Dark"],"type":["Water","Psychic"]},
    {"name":"Misdreavus","hp":60,"damage":60,"weakness":["Ghost","Dark"],"type":["Ghost"]},
    {"name":"Unown","hp":48,"damage":72,"weakness":["Bug","Ghost","Dark"],"type":["Psychic"]},
    {"name":"Wobbuffet","hp":190,"damage":33,"weakness":["Bug","Ghost","Dark"],"type":["Psychic"]},
    {"name":"Girafarig","hp":70,"damage":80,"weakness":["Bug","Dark"],"type":["Normal","Psychic"]},
    {"name":"Pineco","hp":50,"damage":65,"weakness":["Fire","Flying","Rock"],"type":["Bug"]},
    {"name":"Forretress","hp":75,"damage":90,"weakness":["Fire"],"type":["Bug","Steel"]},
    {"name":"Dunsparce","hp":100,"damage":70,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Gligar","hp":65,"damage":75,"weakness":["Water","Ice"],"type":["Ground","Flying"]},
    {"name":"Steelix","hp":75,"damage":85,"weakness":["Fire","Water","Fighting","Ground"],"type":["Steel","Ground"]},
    {"name":"Snubbull","hp":60,"damage":80,"weakness":["Poison","Steel"],"type":["Fairy"]},
    {"name":"Granbull","hp":90,"damage":120,"weakness":["Poison","Steel"],"type":["Fairy"]},
    {"name":"Qwilfish","hp":65,"damage":95,"weakness":["Electric","Ground","Psychic"],"type":["Water","Poison"]},
    {"name":"Scizor","hp":70,"damage":130,"weakness":["Fire"],"type":["Bug","Steel"]},
    {"name":"Shuckle","hp":20,"damage":10,"weakness":["Water","Rock","Steel"],"type":["Bug","Rock"]},
    {"name":"Heracross","hp":80,"damage":125,"weakness":["Fire","Flying","Psychic","Fairy"],"type":["Bug","Fighting"]},
    {"name":"Sneasel","hp":55,"damage":95,"weakness":["Fire","Fighting","Bug","Rock","Steel","Fairy"],"type":["Dark","Ice"]},
    {"name":"Teddiursa","hp":60,"damage":80,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Ursaring","hp":90,"damage":130,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Slugma","hp":40,"damage":40,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Magcargo","hp":60,"damage":50,"weakness":["Water","Ground","Fighting","Rock"],"type":["Fire","Rock"]},
    {"name":"Swinub","hp":50,"damage":50,"weakness":["Fire","Water","Grass","Fighting","Steel"],"type":["Ice","Ground"]},
    {"name":"Piloswine","hp":100,"damage":100,"weakness":["Fire","Water","Grass","Fighting","Steel"],"type":["Ice","Ground"]},
    {"name":"Corsola","hp":65,"damage":55,"weakness":["Electric","Grass","Ground","Fighting"],"type":["Water","Rock"]},
    {"name":"Remoraid","hp":35,"damage":65,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Octillery","hp":75,"damage":105,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Delibird","hp":45,"damage":55,"weakness":["Fire","Electric","Rock","Steel"],"type":["Ice","Flying"]},
    {"name":"Mantine","hp":85,"damage":40,"weakness":["Electric","Rock"],"type":["Water","Flying"]},
    {"name":"Skarmory","hp":65,"damage":80,"weakness":["Fire","Electric"],"type":["Steel","Flying"]},
    {"name":"Houndour","hp":45,"damage":60,"weakness":["Water","Ground","Fighting","Rock"],"type":["Dark","Fire"]},
    {"name":"Houndoom","hp":75,"damage":90,"weakness":["Water","Ground","Fighting","Rock"],"type":["Dark","Fire"]},
    {"name":"Kingdra","hp":75,"damage":95,"weakness":["Dragon","Fairy"],"type":["Water","Dragon"]},
    {"name":"Phanpy","hp":90,"damage":60,"weakness":["Water","Grass","Ice"],"type":["Ground"]},
    {"name":"Donphan","hp":90,"damage":120,"weakness":["Water","Grass","Ice"],"type":["Ground"]},
    {"name":"Porygon2","hp":85,"damage":80,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Stantler","hp":73,"damage":95,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Smeargle","hp":55,"damage":20,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Tyrogue","hp":35,"damage":35,"weakness":["Flying","Psychic","Fairy"],"type":["Fighting"]},
    {"name":"Hitmontop","hp":50,"damage":95,"weakness":["Flying","Psychic","Fairy"],"type":["Fighting"]},
    {"name":"Smoochum","hp":45,"damage":30,"weakness":["Fire","Bug","Rock","Ghost","Dark","Steel"],"type":["Ice","Psychic"]},
    {"name":"Elekid","hp":45,"damage":63,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Magby","hp":45,"damage":75,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Miltank","hp":95,"damage":80,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Blissey","hp":255,"damage":10,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Raikou","hp":90,"damage":85,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Entei","hp":115,"damage":115,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Suicune","hp":100,"damage":75,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Larvitar","hp":50,"damage":64,"weakness":["Water","Grass","Ice","Fighting","Ground","Bug","Steel","Fairy"],"type":["Rock","Ground"]},
    {"name":"Pupitar","hp":70,"damage":84,"weakness":["Water","Grass","Ice","Fighting","Ground","Bug","Steel","Fairy"],"type":["Rock","Ground"]},
    {"name":"Tyranitar","hp":100,"damage":134,"weakness":["Water","Grass","Ice","Fighting","Ground","Bug","Steel","Fairy"],"type":["Rock","Dark"]},
    {"name":"Lugia","hp":106,"damage":90,"weakness":["Electric","Ice","Rock","Ghost","Dark"],"type":["Psychic","Flying"]},
    {"name":"Ho-Oh","hp":106,"damage":130,"weakness":["Water","Electric","Rock"],"type":["Fire","Flying"]},
    {"name":"Celebi","hp":100,"damage":100,"weakness":["Fire","Ice","Flying","Bug","Ghost","Dark"],"type":["Psychic","Grass"]}
]

gen3_pokemon = [
    {"name":"Treecko","hp":40,"damage":45,"weakness":["Fire","Ice","Flying","Bug","Poison"],"type":["Grass"]},
    {"name":"Grovyle","hp":50,"damage":65,"weakness":["Fire","Ice","Flying","Bug","Poison"],"type":["Grass"]},
    {"name":"Sceptile","hp":70,"damage":85,"weakness":["Fire","Ice","Flying","Bug","Poison"],"type":["Grass"]},

    {"name":"Torchic","hp":45,"damage":60,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Combusken","hp":60,"damage":85,"weakness":["Water","Ground","Flying","Psychic"],"type":["Fire","Fighting"]},
    {"name":"Blaziken","hp":80,"damage":120,"weakness":["Water","Ground","Flying","Psychic"],"type":["Fire","Fighting"]},

    {"name":"Mudkip","hp":50,"damage":70,"weakness":["Grass"],"type":["Water"]},
    {"name":"Marshtomp","hp":70,"damage":85,"weakness":["Grass"],"type":["Water","Ground"]},
    {"name":"Swampert","hp":100,"damage":110,"weakness":["Grass"],"type":["Water","Ground"]},

    {"name":"Poochyena","hp":35,"damage":55,"weakness":["Fighting","Bug","Fairy"],"type":["Dark"]},
    {"name":"Mightyena","hp":70,"damage":90,"weakness":["Fighting","Bug","Fairy"],"type":["Dark"]},

    {"name":"Zigzagoon","hp":38,"damage":30,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Linoone","hp":78,"damage":70,"weakness":["Fighting"],"type":["Normal"]},

    {"name":"Wurmple","hp":45,"damage":45,"weakness":["Fire","Flying","Rock"],"type":["Bug"]},
    {"name":"Silcoon","hp":50,"damage":35,"weakness":["Fire","Flying","Rock"],"type":["Bug"]},
    {"name":"Beautifly","hp":60,"damage":70,"weakness":["Fire","Electric","Ice","Flying","Rock"],"type":["Bug","Flying"]},
    {"name":"Cascoon","hp":50,"damage":35,"weakness":["Fire","Flying","Rock"],"type":["Bug"]},
    {"name":"Dustox","hp":60,"damage":50,"weakness":["Fire","Flying","Psychic","Rock"],"type":["Bug","Poison"]},

    {"name":"Lotad","hp":40,"damage":30,"weakness":["Flying","Bug","Poison"],"type":["Water","Grass"]},
    {"name":"Lombre","hp":60,"damage":50,"weakness":["Flying","Bug","Poison"],"type":["Water","Grass"]},
    {"name":"Ludicolo","hp":80,"damage":70,"weakness":["Flying","Bug","Poison"],"type":["Water","Grass"]},

    {"name":"Seedot","hp":40,"damage":40,"weakness":["Fire","Ice","Flying","Bug","Fighting","Poison","Fairy"],"type":["Grass"]},
    {"name":"Nuzleaf","hp":70,"damage":70,"weakness":["Fire","Ice","Flying","Bug","Fighting","Poison","Fairy"],"type":["Grass","Dark"]},
    {"name":"Shiftry","hp":90,"damage":100,"weakness":["Fire","Ice","Flying","Bug","Fighting","Poison","Fairy"],"type":["Grass","Dark"]},

    {"name":"Taillow","hp":40,"damage":55,"weakness":["Electric","Ice","Rock"],"type":["Normal","Flying"]},
    {"name":"Swellow","hp":60,"damage":85,"weakness":["Electric","Ice","Rock"],"type":["Normal","Flying"]},

    {"name":"Wingull","hp":40,"damage":30,"weakness":["Electric","Rock"],"type":["Water","Flying"]},
    {"name":"Pelipper","hp":60,"damage":50,"weakness":["Electric","Rock"],"type":["Water","Flying"]},

    {"name":"Ralts","hp":28,"damage":25,"weakness":["Ghost","Poison","Steel"],"type":["Psychic","Fairy"]},
    {"name":"Kirlia","hp":38,"damage":35,"weakness":["Ghost","Poison","Steel"],"type":["Psychic","Fairy"]},
    {"name":"Gardevoir","hp":68,"damage":65,"weakness":["Ghost","Poison","Steel"],"type":["Psychic","Fairy"]},

    {"name":"Surskit","hp":40,"damage":30,"weakness":["Electric","Flying","Rock"],"type":["Bug","Water"]},
    {"name":"Masquerain","hp":70,"damage":60,"weakness":["Electric","Ice","Flying","Rock"],"type":["Bug","Flying"]},

    {"name":"Shroomish","hp":60,"damage":40,"weakness":["Fire","Ice","Flying","Poison","Bug"],"type":["Grass"]},
    {"name":"Breloom","hp":60,"damage":130,"weakness":["Fire","Ice","Psychic","Flying","Poison","Fairy"],"type":["Grass","Fighting"]},

    {"name":"Slakoth","hp":60,"damage":60,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Vigoroth","hp":80,"damage":80,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Slaking","hp":150,"damage":160,"weakness":["Fighting"],"type":["Normal"]},

    {"name":"Makuhita","hp":72,"damage":60,"weakness":["Flying","Psychic","Fairy"],"type":["Fighting"]},
    {"name":"Hariyama","hp":144,"damage":120,"weakness":["Flying","Psychic","Fairy"],"type":["Fighting"]},

    {"name":"Nosepass","hp":30,"damage":45,"weakness":["Water","Grass","Fighting","Ground","Steel"],"type":["Rock"]},

    {"name":"Skitty","hp":50,"damage":45,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Delcatty","hp":70,"damage":65,"weakness":["Fighting"],"type":["Normal"]},

    {"name":"Sableye","hp":50,"damage":75,"weakness":["Fairy"],"type":["Dark","Ghost"]},
    {"name":"Mawile","hp":50,"damage":85,"weakness":["Fire","Ground"],"type":["Steel","Fairy"]},

    {"name":"Aron","hp":50,"damage":70,"weakness":["Water","Fighting","Ground"],"type":["Steel","Rock"]},
    {"name":"Lairon","hp":60,"damage":90,"weakness":["Water","Fighting","Ground"],"type":["Steel","Rock"]},
    {"name":"Aggron","hp":70,"damage":110,"weakness":["Water","Fighting","Ground"],"type":["Steel","Rock"]},

    {"name":"Meditite","hp":30,"damage":40,"weakness":["Flying","Ghost","Fairy"],"type":["Fighting","Psychic"]},
    {"name":"Medicham","hp":60,"damage":60,"weakness":["Flying","Ghost","Fairy"],"type":["Fighting","Psychic"]},

    {"name":"Electrike","hp":40,"damage":45,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Manectric","hp":70,"damage":75,"weakness":["Ground"],"type":["Electric"]},

    {"name":"Plusle","hp":60,"damage":50,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Minun","hp":60,"damage":40,"weakness":["Ground"],"type":["Electric"]},

    {"name":"Volbeat","hp":65,"damage":73,"weakness":["Fire","Flying","Rock"],"type":["Bug"]},
    {"name":"Illumise","hp":65,"damage":47,"weakness":["Fire","Flying","Rock"],"type":["Bug"]},

    {"name":"Roselia","hp":50,"damage":60,"weakness":["Fire","Ice","Flying","Psychic"],"type":["Grass","Poison"]},

    {"name":"Gulpin","hp":70,"damage":43,"weakness":["Ground","Psychic"],"type":["Poison"]},
    {"name":"Swalot","hp":100,"damage":73,"weakness":["Ground","Psychic"],"type":["Poison"]},

    {"name":"Carvanha","hp":45,"damage":90,"weakness":["Electric","Grass","Fighting","Bug","Fairy"],"type":["Water","Dark"]},
    {"name":"Sharpedo","hp":70,"damage":120,"weakness":["Electric","Grass","Fighting","Bug","Fairy"],"type":["Water","Dark"]},

    {"name":"Bagon","hp":45,"damage":75,"weakness":["Ice","Dragon","Fairy"],"type":["Dragon"]},
    {"name":"Shelgon","hp":65,"damage":95,"weakness":["Ice","Dragon","Fairy"],"type":["Dragon"]},
    {"name":"Salamence","hp":95,"damage":135,"weakness":["Ice","Dragon","Fairy","Rock"],"type":["Dragon","Flying"]},

    {"name":"Beldum","hp":40,"damage":55,"weakness":["Fire","Ground","Ghost","Dark"],"type":["Steel","Psychic"]},
    {"name":"Metang","hp":60,"damage":75,"weakness":["Fire","Ground","Ghost","Dark"],"type":["Steel","Psychic"]},
    {"name":"Metagross","hp":80,"damage":135,"weakness":["Fire","Ground","Ghost","Dark"],"type":["Steel","Psychic"]},

    {"name":"Regirock","hp":80,"damage":100,"weakness":["Water","Grass","Fighting","Ground","Steel"],"type":["Rock"]},
    {"name":"Regice","hp":80,"damage":50,"weakness":["Fire","Fighting","Rock","Steel"],"type":["Ice"]},
    {"name":"Registeel","hp":80,"damage":75,"weakness":["Fire","Fighting","Ground"],"type":["Steel"]},

    {"name":"Latias","hp":80,"damage":80,"weakness":["Ice","Dragon","Bug","Ghost","Dark","Fairy"],"type":["Dragon","Psychic"]},
    {"name":"Latios","hp":80,"damage":90,"weakness":["Ice","Dragon","Bug","Ghost","Dark","Fairy"],"type":["Dragon","Psychic"]},

    {"name":"Kyogre","hp":100,"damage":100,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Groudon","hp":100,"damage":150,"weakness":["Water","Grass","Ice"],"type":["Ground"]},
    {"name":"Rayquaza","hp":105,"damage":150,"weakness":["Ice","Dragon","Fairy","Rock"],"type":["Dragon","Flying"]},

    {"name":"Jirachi","hp":100,"damage":100,"weakness":["Fire","Ground","Ghost","Dark"],"type":["Steel","Psychic"]},
    {"name":"Deoxys","hp":50,"damage":150,"weakness":["Bug","Ghost","Dark"],"type":["Psychic"]}
]

gen4_pokemon = [
    {"name":"Turtwig","hp":55,"damage":68,"weakness":["Fire","Ice","Flying","Bug"],"type":["Grass"]},
    {"name":"Grotle","hp":75,"damage":89,"weakness":["Fire","Ice","Flying","Bug"],"type":["Grass"]},
    {"name":"Torterra","hp":95,"damage":109,"weakness":["Fire","Ice","Flying","Bug"],"type":["Grass","Ground"]},

    {"name":"Chimchar","hp":44,"damage":58,"weakness":["Water","Ground","Psychic","Flying"],"type":["Fire"]},
    {"name":"Monferno","hp":64,"damage":78,"weakness":["Water","Ground","Psychic","Flying"],"type":["Fire","Fighting"]},
    {"name":"Infernape","hp":76,"damage":104,"weakness":["Water","Ground","Psychic","Flying"],"type":["Fire","Fighting"]},

    {"name":"Piplup","hp":53,"damage":51,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Prinplup","hp":64,"damage":66,"weakness":["Electric","Grass","Fighting","Ground"],"type":["Water","Steel"]},
    {"name":"Empoleon","hp":84,"damage":86,"weakness":["Electric","Grass","Fighting","Ground"],"type":["Water","Steel"]},

    {"name":"Starly","hp":40,"damage":55,"weakness":["Electric","Ice","Rock"],"type":["Normal","Flying"]},
    {"name":"Staravia","hp":55,"damage":75,"weakness":["Electric","Ice","Rock"],"type":["Normal","Flying"]},
    {"name":"Staraptor","hp":85,"damage":120,"weakness":["Electric","Ice","Rock"],"type":["Normal","Flying"]},

    {"name":"Bidoof","hp":59,"damage":45,"weakness":["Fighting","Grass"],"type":["Normal"]},
    {"name":"Bibarel","hp":79,"damage":85,"weakness":["Fighting","Grass","Electric"],"type":["Normal","Water"]},

    {"name":"Kricketot","hp":37,"damage":25,"weakness":["Fire","Flying","Rock"],"type":["Bug"]},
    {"name":"Kricketune","hp":77,"damage":85,"weakness":["Fire","Flying","Rock"],"type":["Bug"]},

    {"name":"Shinx","hp":45,"damage":65,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Luxio","hp":60,"damage":85,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Luxray","hp":80,"damage":120,"weakness":["Ground"],"type":["Electric"]},

    {"name":"Budew","hp":40,"damage":30,"weakness":["Fire","Ice","Flying","Psychic"],"type":["Grass","Poison"]},
    {"name":"Roserade","hp":60,"damage":70,"weakness":["Fire","Ice","Flying","Psychic"],"type":["Grass","Poison"]},

    {"name":"Cranidos","hp":67,"damage":125,"weakness":["Water","Grass","Fighting","Ground","Steel"],"type":["Rock"]},
    {"name":"Rampardos","hp":97,"damage":165,"weakness":["Water","Grass","Fighting","Ground","Steel"],"type":["Rock"]},

    {"name":"Shieldon","hp":30,"damage":42,"weakness":["Water","Fighting","Ground"],"type":["Rock","Steel"]},
    {"name":"Bastiodon","hp":60,"damage":52,"weakness":["Water","Fighting","Ground"],"type":["Rock","Steel"]},

    {"name":"Burmy","hp":40,"damage":29,"weakness":["Fire","Flying","Rock"],"type":["Bug"]},
    {"name":"Wormadam","hp":60,"damage":59,"weakness":["Fire","Flying","Rock"],"type":["Bug","Grass"]},
    {"name":"Mothim","hp":70,"damage":94,"weakness":["Fire","Electric","Ice","Flying","Rock"],"type":["Bug","Flying"]},

    {"name":"Combee","hp":30,"damage":30,"weakness":["Fire","Electric","Ice","Flying","Rock"],"type":["Bug","Flying"]},
    {"name":"Vespiquen","hp":70,"damage":80,"weakness":["Fire","Electric","Ice","Flying","Rock"],"type":["Bug","Flying"]},

    {"name":"Pachirisu","hp":60,"damage":45,"weakness":["Ground"],"type":["Electric"]},

    {"name":"Buizel","hp":55,"damage":65,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Floatzel","hp":85,"damage":105,"weakness":["Electric","Grass"],"type":["Water"]},

    {"name":"Cherubi","hp":45,"damage":35,"weakness":["Fire","Ice","Flying","Bug","Poison"],"type":["Grass"]},
    {"name":"Cherrim","hp":70,"damage":60,"weakness":["Fire","Ice","Flying","Bug","Poison"],"type":["Grass"]},

    {"name":"Shellos","hp":76,"damage":48,"weakness":["Grass"],"type":["Water"]},
    {"name":"Gastrodon","hp":111,"damage":83,"weakness":["Grass"],"type":["Water","Ground"]},

    {"name":"Ambipom","hp":75,"damage":100,"weakness":["Fighting"],"type":["Normal"]},

    {"name":"Drifloon","hp":90,"damage":50,"weakness":["Electric","Ice","Rock","Ghost","Dark"],"type":["Ghost","Flying"]},
    {"name":"Drifblim","hp":150,"damage":80,"weakness":["Electric","Ice","Rock","Ghost","Dark"],"type":["Ghost","Flying"]},

    {"name":"Buneary","hp":55,"damage":66,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Lopunny","hp":65,"damage":76,"weakness":["Fighting"],"type":["Normal"]},

    {"name":"Mismagius","hp":60,"damage":60,"weakness":["Ghost","Dark"],"type":["Ghost"]},

    {"name":"Honchkrow","hp":100,"damage":125,"weakness":["Electric","Ice","Rock","Fairy"],"type":["Dark","Flying"]},

    {"name":"Spiritomb","hp":50,"damage":92,"weakness":["Fairy"],"type":["Ghost","Dark"]},

    {"name":"Gible","hp":58,"damage":70,"weakness":["Ice","Dragon","Fairy"],"type":["Dragon","Ground"]},

    {"name":"Gible","hp":58,"damage":70,"weakness":["Ice","Dragon","Fairy"],"type":["Dragon","Ground"]},
    {"name":"Gabite","hp":68,"damage":90,"weakness":["Ice","Dragon","Fairy"],"type":["Dragon","Ground"]},
    {"name":"Garchomp","hp":108,"damage":130,"weakness":["Ice","Dragon","Fairy"],"type":["Dragon","Ground"]},

    {"name":"Riolu","hp":40,"damage":70,"weakness":["Fire","Fighting","Ground"],"type":["Fighting"]},
    {"name":"Lucario","hp":70,"damage":110,"weakness":["Fire","Fighting","Ground"],"type":["Fighting","Steel"]},

    {"name":"Skorupi","hp":40,"damage":50,"weakness":["Fire","Flying","Rock"],"type":["Poison","Bug"]},
    {"name":"Drapion","hp":70,"damage":90,"weakness":["Ground"],"type":["Poison","Dark"]},

    {"name":"Croagunk","hp":48,"damage":61,"weakness":["Ground","Psychic","Flying"],"type":["Poison","Fighting"]},
    {"name":"Toxicroak","hp":83,"damage":106,"weakness":["Ground","Psychic","Flying"],"type":["Poison","Fighting"]},

    {"name":"Snover","hp":60,"damage":62,"weakness":["Fire","Flying","Bug","Rock","Steel","Fighting"],"type":["Grass","Ice"]},
    {"name":"Abomasnow","hp":90,"damage":92,"weakness":["Fire","Flying","Bug","Rock","Steel","Fighting"],"type":["Grass","Ice"]},

    {"name":"Weavile","hp":70,"damage":120,"weakness":["Fire","Fighting","Bug","Rock","Steel","Fairy"],"type":["Dark","Ice"]},
    {"name":"Magnezone","hp":70,"damage":70,"weakness":["Fire","Fighting","Ground"],"type":["Electric","Steel"]},
    {"name":"Rhyperior","hp":115,"damage":140,"weakness":["Water","Grass","Ice","Fighting","Ground","Steel"],"type":["Ground","Rock"]},
    {"name":"Electivire","hp":75,"damage":123,"weakness":["Ground"],"type":["Electric"]},
    {"name":"Magmortar","hp":75,"damage":95,"weakness":["Water","Ground","Rock"],"type":["Fire"]},
    {"name":"Togekiss","hp":85,"damage":50,"weakness":["Electric","Ice","Poison","Rock","Steel"],"type":["Fairy","Flying"]},
    {"name":"Yanmega","hp":86,"damage":76,"weakness":["Fire","Electric","Ice","Flying","Rock"],"type":["Bug","Flying"]},
    {"name":"Leafeon","hp":65,"damage":110,"weakness":["Fire","Ice","Flying","Bug","Poison"],"type":["Grass"]},
    {"name":"Glaceon","hp":65,"damage":60,"weakness":["Fire","Fighting","Rock","Steel"],"type":["Ice"]},
    {"name":"Gliscor","hp":75,"damage":95,"weakness":["Water","Ice"],"type":["Ground","Flying"]},
    {"name":"Mamoswine","hp":110,"damage":130,"weakness":["Fire","Water","Grass","Fighting","Steel"],"type":["Ice","Ground"]},
    {"name":"Porygon-Z","hp":85,"damage":80,"weakness":["Fighting"],"type":["Normal"]},

    {"name":"Uxie","hp":75,"damage":75,"weakness":["Bug","Ghost","Dark"],"type":["Psychic"]},
    {"name":"Mesprit","hp":80,"damage":105,"weakness":["Bug","Ghost","Dark"],"type":["Psychic"]},
    {"name":"Azelf","hp":75,"damage":125,"weakness":["Bug","Ghost","Dark"],"type":["Psychic"]},

    {"name":"Dialga","hp":100,"damage":120,"weakness":["Fighting","Ground"],"type":["Steel","Dragon"]},
    {"name":"Palkia","hp":90,"damage":120,"weakness":["Dragon","Fairy"],"type":["Water","Dragon"]},
    {"name":"Heatran","hp":91,"damage":90,"weakness":["Water","Fighting","Ground"],"type":["Fire","Steel"]},
    {"name":"Regigigas","hp":110,"damage":160,"weakness":["Fighting"],"type":["Normal"]},
    {"name":"Giratina","hp":150,"damage":100,"weakness":["Ice","Dragon","Ghost","Dark","Fairy"],"type":["Ghost","Dragon"]},
    {"name":"Cresselia","hp":120,"damage":70,"weakness":["Bug","Ghost","Dark"],"type":["Psychic"]},

    {"name":"Phione","hp":80,"damage":80,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Manaphy","hp":100,"damage":100,"weakness":["Electric","Grass"],"type":["Water"]},
    {"name":"Darkrai","hp":70,"damage":90,"weakness":["Fighting","Bug","Fairy"],"type":["Dark"]},
    {"name":"Shaymin","hp":100,"damage":100,"weakness":["Fire","Ice","Flying","Bug","Poison"],"type":["Grass"]},
    {"name":"Arceus","hp":120,"damage":120,"weakness":[],"type":["Normal"]}
]

# %%
import random

# %%
if random.randint(1,4)== 1:
  x = gen1_pokemon[random.randint(0,len(gen1_pokemon)-1)]
  print(x)
elif random.randint(1,3)==1:
  x = gen2_pokemon[random.randint(0,len(gen2_pokemon)-1)]
  print(x)
elif random.randint(1,2)==1:
  x = gen3_pokemon[random.randint(0,len(gen3_pokemon)-1)]
  print(x)
else:
  x = gen4_pokemon[random.randint(0,len(gen4_pokemon)-1)]
  print(x)
# Out:
# {'name': 'Tentacruel', 'hp': 80, 'damage': 70, 'weakness': ['Electric', 'Ground', 'Psychic'], 'type': ['Water', 'Poison']}

# %%
l = []
for i in gen1_pokemon:
  if x['hp'] == i['hp']:
    l.append(i)
for i in gen2_pokemon:
  if x['hp'] == i['hp']:
    l.append(i)
for i in gen3_pokemon:
  if x['hp'] == i['hp']:
    l.append(i)
for i in gen4_pokemon:
  if x['hp'] == i['hp']:
    l.append(i)
m = []
for i in l:
  if i['damage']==x['damage']:
    m.append(i)
n = []
for i in m:
  if i['type'][0] == x['type'][0]:
    n.append(i)
o = []
for i in n:
  if i['type'][-1] == x['type'][-1]:
    o.append(i)
p = []
for i in o:
  if i['weakness'][-1] == x['weakness'][-1]:
    p.append(i)
for i in p:
  print(i['name'])
# Out:
# Tentacruel
