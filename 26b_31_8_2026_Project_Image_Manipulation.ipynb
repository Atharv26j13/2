# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharv26j13/2/blob/main/26b_31_8_2026_Project_Image_Manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files = files.upload()
# Out:
#      <input type="file" id="files-60809a08-7086-4a79-9536-069dc3f7734a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-60809a08-7086-4a79-9536-069dc3f7734a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread("project-hail-mary-movie-poster.jpg")

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.title("RGB Image")
plt.show()

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray,cmap="gray")
plt.title("Grayscale Image")
plt.show()

# %%
cropped_Image = image_rgb[100:300, 200:400]
plt.imshow(cropped_Image)
plt.title("Cropped Image")
plt.show()

# %%
(h,w) = image_rgb.shape[:2]
center = (w/2,h/2)
M = cv2.getRotationMatrix2D(center,45,1.0)
rotated = cv2.warpAffine(image_rgb,M,(w,h))
plt.imshow(rotated)
plt.title("Rotated Image")
plt.show()

# %%
bm = np.ones(image_rgb.shape,dtype="uint8")*100
added = cv2.add(image_rgb,bm)

plt.imshow(added)
plt.title("Brighter Image")
plt.show()
