# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharv26j13/2/blob/main/NETFLIX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = []
class WATCH:
  def __init__(self,name,mos,genre,length,yearor,rating):
    self.name=name
    self.mos=mos
    self.genre=genre
    self.length=length
    self.yearor=yearor
    self.rating=rating
    l.append(self)

CONJURING = WATCH("CONJURING","Movie","Horror",120,2015,9)
CONJURING2 = WATCH("CONJURING 2","Movie","Horror",120,2016,7)
DUNE = WATCH("DUNE","Movie","Sci-Fi",150,2022,9.5)
DUNE2 = WATCH("DUNE 2","Movie","Sci-Fi",180,2025,8)
F1 = WATCH("F1","Movie","Racing",170,2025,9.5)
FASTANDFURIOUS = WATCH("FAST AND FURIOUS","Movie","Action",120,2017,9)
FASTANDFURIOUS2 = WATCH("FAST AND FURIOUS 2","Movie","Action",100,2019,8)
FASTANDFURIOUS3 = WATCH("FAST AND FURIOUS 3","Movie","Action",120,2020,9)
FASTANDFURIOUS4 = WATCH("FAST AND FURIOUS 4","Movie","Action",140,2022,7)
SONIC = WATCH("SONIC","Movie","Action",100,2020,7)
SONIC2 = WATCH("SONIC 2","Movie","Action",120,2022,8)
SONIC3 = WATCH("SONIC 3","Movie","Action",150,2025,9.5)
JJK0 = WATCH("Jujutsu Kaisen 0","Movie","Anime",120,2020,8)
JJK = WATCH("Jujutsu Kaisen","Show","Anime",3,2019,9)
NARUTO = WATCH("Naruto","Show","Anime",9,2015,8.5)
POP = WATCH("Prince of Peoria","Show","Comedy",2,2017,7)
TEENTITANSGO = WATCH("Teen Titans Go","Show","Comedy",5,2015,7)
GOKU = WATCH("Naruto","Show","Anime",9,2015,8.5)

def p3():
  x = 0
  a = input("\nSEARCH:")
  print("Results:")
  for i in l:
    if i.name == a:
      print(i.name)
      x = 1
    elif i.name.startswith(a):
      print(i.name)
      x = 1
    elif i.genre == a:
      print(i.name)
      x = 1
  if x == 0:
    print("NO RESULTS FOUND\nTRY AGAIN:\n")
    p3()


def p2():
  x = 0
  a = input("By what do you want to search?\n1.Name\n2.Genre\n3.Length\n4.Rating\n")
  a = int(a)

  if a == 1:
    b = input("\nENTER NAME:")
    print("Results:")
    for i in l:
      if i.name == b:
        print(i.name)
        x = 1

  elif a == 2:
    b = input("\nENTER GENRE:")
    print("Results:")
    for i in l:
      if i.genre == b:
        print(i.name)
        x = 1

  elif a == 3:
    b = int(input("\nENTER MINIMUM LENGTH:"))
    c = int(input("\nENTER MAXIMUM LENGTH:"))
    print("Results:")
    for i in l:
      if i.length >= b and i.length <= c:
        print(i.name)
        x = 1

  elif a == 4:   # ← FIXED (was duplicate 3)
    b = float(input("\nENTER RATING:"))
    print("Results:")
    for i in l:
      if i.rating == b:
        print(i.name)
        x = 1

  else:
    print("INVALID INPUT")
    p2()
    return

  if x == 0:
    print("NO RESULTS FOUND\nTRY AGAIN:\n")
    p2()


def NETFLIX():
  print("Welcome to NETFLIX")
  print("What would you like to watch?")
  a = int(input("1:Most Watched\n2:Find\n3:Search\n"))
  x = 0

  if a == 1:
    print("\nMost Watched:")
    print("1.CONJURING")
    print("2.DUNE")
    print("3.F1")
    print("4.FASTANDFURIOUS")
    print("5.SONIC")

  elif a == 3:
    p3()

  elif a== 2:
    p2()

  a = input("\nWHICH ONE WOULD YOU LIKE TO WATCH?:")
  for i in l:
    if i.name == a:
      print(i.name)
      print(i.mos)
      print(i.genre)
      print(i.yearor)
      if (i.mos == "Movie"):
        print("Minutes: ",i.length)
      if (i.mos == "Show"):
        print("Seasons: ",i.length)
      x = 1

  if x == 0:
    print("NONE FOUND BY THIS NAME")

  input("Press enter to go home:")
  NETFLIX()

NETFLIX()
# Out:
# Welcome to NETFLIX
# What would you like to watch?
# 1:Most Watched
# 2:Find
# 3:Search
# 3
#
# SEARCH:DUNE
# Results:
# DUNE
# DUNE 2
#
# WHICH ONE WOULD YOU LIKE TO WATCH?:DUNE 2
# DUNE 2
# Movie
# Sci-Fi
# 2025
# Minutes:  180
# Press enter to go home:
# Welcome to NETFLIX
# What would you like to watch?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-743228631.py in <cell line: 0>()
#     135   NETFLIX()
#     136
# --> 137 NETFLIX()
#
# /tmp/ipython-input-743228631.py in NETFLIX()
#     133
#     134   input("Press enter to go home:")
# --> 135   NETFLIX()
#     136
#     137 NETFLIX()
#
# /tmp/ipython-input-743228631.py in NETFLIX()
#      99   print("Welcome to NETFLIX")
#     100   print("What would you like to watch?")
# --> 101   a = int(input("1:Most Watched\n2:Find\n3:Search\n"))
#     102   x = 0
#     103
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
