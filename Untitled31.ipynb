# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharv26j13/2/blob/main/Untitled31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy.stats as stats
prob = 1-stats.binom.cdf(6,10,0.5)
print(prob)
# Out:
# 0.171875

# %%
import scipy.stats as stats
prob = stats.poisson.pmf(6,10)
print(prob)
# Out:
# 0.06305545800345125

# %%
import scipy.stats as stats
print(stats.poisson.pmf(12,10)+stats.poisson.pmf(13,10)+stats.poisson.pmf(14,10))
# Out:
# 0.21976538076223123

# %%
print(1/2**3)
# Out:
# 0.125

# %%
import scipy.stats as stats
print(stats.poisson.cdf(20,15))
# Out:
# 0.9170290899685397
