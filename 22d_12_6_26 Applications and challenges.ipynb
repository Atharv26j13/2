# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharv26j13/2/blob/main/22d_12_6_26%20Applications%20and%20challenges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import random

# %%
l = []
a = ''
b = ''
c = ''
for i in range(int(input("Enter length: "))):
  if random.randint(1,3) == 1:
    a = 'Strong'
  elif random.randint(1,2) == 2:
    a = 'Medium'
  else:
    a = 'Weak'
  if random.randint(1,3) == 1:
    b = 'Attacker'
  elif random.randint(1,2) == 2:
    b = 'Supporter'
  else:
    b = 'Healer'
  if random.randint(1,3) == 1:
    c = 'Intelligent'
  elif random.randint(1,2) == 2:
    c = 'Normal'
  else:
    c = 'Dumb'
  l.append([a,b,c])
print(l)
# Out:
# Enter length: 10000
# ...

# %%
#Supervised

sai = []
san = []
sad = []
ssi = []
ssn = []
ssd = []
shi = []
shn = []
shd = []

mai = []
man = []
mad = []
msi = []
msn = []
msd = []
mhi = []
mhn = []
mhd = []

wai = []
wan = []
wad = []
wsi = []
wsn = []
wsd = []
whi = []
whn = []
whd = []

for i in l:
  if i[0] == 'Strong':
    if i[1] == 'Attacker':
      if i[2] == 'Intelligent':
        sai.append(i)
      if i[2] == 'Normal':
        san.append(i)
      if i[2] == 'Dumb':
        sad.append(i)
    if i[1] == 'Supporter':
      if i[2] == 'Intelligent':
        ssi.append(i)
      if i[2] == 'Normal':
        ssn.append(i)
      if i[2] == 'Dumb':
        ssd.append(i)
    if i[1] == 'Healer':
      if i[2] == 'Intelligent':
        shi.append(i)
      if i[2] == 'Normal':
        shn.append(i)
      if i[2] == 'Dumb':
        shd.append(i)

  if i[0] == 'Medium':
    if i[1] == 'Attacker':
      if i[2] == 'Intelligent':
        mai.append(i)
      if i[2] == 'Normal':
        man.append(i)
      if i[2] == 'Dumb':
        mad.append(i)
    if i[1] == 'Supporter':
      if i[2] == 'Intelligent':
        msi.append(i)
      if i[2] == 'Normal':
        msn.append(i)
      if i[2] == 'Dumb':
        msd.append(i)
    if i[1] == 'Healer':
      if i[2] == 'Intelligent':
        mhi.append(i)
      if i[2] == 'Normal':
        mhn.append(i)
      if i[2] == 'Dumb':
        mhd.append(i)

  if i[0] == 'Weak':
    if i[1] == 'Attacker':
      if i[2] == 'Intelligent':
        wai.append(i)
      if i[2] == 'Normal':
        wan.append(i)
      if i[2] == 'Dumb':
        wad.append(i)
    if i[1] == 'Supporter':
      if i[2] == 'Intelligent':
        wsi.append(i)
      if i[2] == 'Normal':
        wsn.append(i)
      if i[2] == 'Dumb':
        wsd.append(i)
    if i[1] == 'Healer':
      if i[2] == 'Intelligent':
        whi.append(i)
      if i[2] == 'Normal':
        whn.append(i)
      if i[2] == 'Dumb':
        whd.append(i)

print(len(sai))
print(len(san))
print(len(sad))
print(len(ssi))
print(len(ssn))
print(len(ssd))
print(len(shi))
print(len(shn))
print(len(shd))
print(len(mai))
print(len(man))
print(len(mad))
print(len(msi))
print(len(msn))
print(len(msd))
print(len(mhi))
print(len(mhn))
print(len(mhd))
print(len(wai))
print(len(wan))
print(len(wad))
print(len(wsi))
print(len(wsn))
print(len(wsd))
print(len(whi))
print(len(whn))
print(len(whd))
# Out:
# 365
# 380
# 359
# 388
# 364
# 383
# 353
# 361
# 355
# 361
# 382
# 386
# 373
# 383
# 343
# 386
# 360
# 382
# 352
# 334
# 359
# 416
# 352
# 384
# 386
# 374
# 379
