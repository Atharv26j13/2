# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharv26j13/2/blob/main/23c_26_6_26_Color_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-29363653-b278-4d96-b51d-6be01146cfe1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-29363653-b278-4d96-b51d-6be01146cfe1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('shapes.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=640x480>

# %%
hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
cv2_imshow(hsv_img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
lower_blue = np.array([65,0,0])
upper_blue = np.array([110,255,255])

# %%
mask = cv2.inRange(hsv_img, lower_blue, upper_blue)
cv2_imshow(mask)
# Out:
# <PIL.Image.Image image mode=L size=640x480>

# %%
result = cv2.bitwise_and(img, img, mask=mask)
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>
