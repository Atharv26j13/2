# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharv26j13/2/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import random

years = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
sales = [random.randint(1,1000) for i in range(16)]

plt.plot(years,sales,)
plt.show()
plt.bar(years,sales)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

years = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
sales = [random.randint(1,1000) for i in range(16)]

plt.plot(years,sales,'o')
plt.show()
plt.bar(years,sales,)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

years = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
sales = [random.randint(1,1000) for i in range(16)]

plt.plot(years,sales,'r')
plt.show()
plt.bar(years,sales)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

years = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
sales = [random.randint(1,1000) for i in range(16)]

plt.plot(years,sales,linestyle = 'dotted')
plt.show()
plt.bar(years,sales)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

years = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
sales = [random.randint(1,1000) for i in range(16)]

plt.plot(years,sales,'o',ms = 10,mec = 'b')
plt.show()
plt.bar(years,sales)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

years = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
sales = [random.randint(1,1000) for i in range(16)]

plt.plot(years,sales,'r',linewidth = 5)
plt.show()
plt.bar(years,sales)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

years = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
sales = [random.randint(1,1000) for i in range(16)]

plt.plot(years,sales,'r')
plt.plot(years,sales,'o',ms = 10,c = 'b')
plt.plot(years,sales,'o')
plt.show()
plt.bar(years,sales)
plt.show()
