# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharv26j13/2/blob/main/21d_18_5_26_Colour_Spectrum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Colour recogniser#

red = int(input("Enter R value for your colour:\n"))
green = int(input("Enter G value for your colour:\n"))
blue = int(input("Enter B value for your colour:\n"))
if red == green == blue:
  #Grey Spectrum#
  if red == 255:
    print("Perfect White")
  elif red > 224 and red < 256:
    print("Light Grey")
  elif red > 192 and red < 225:
    print("Medium Light Grey")
  elif red > 160 and red < 193:
    print("Medium Grey")
  elif red > 128 and red < 161:
    print("Medium Dark Grey")
  elif red > 96 and red < 129:
    print("Dark Grey")
  elif red > 64 and red < 97:
    print("Very Dark Grey")
  elif red > 32 and red < 65:
    print("Light Black")
  elif red > 0 and red < 33:
    print("Medium Black")
  elif red == 0:
    print("Perfect Black")

elif red == 255 and green == blue:
  if green == 0 and blue == 0:
    print("Perfect Red")
  elif green > 0 and green < 51:
    print("Bright Red")
  elif green > 50 and green < 102:
    print("Light Red")
  elif green > 101 and green < 153:
    print("Very Light Red")
  elif green > 152 and green < 204:
    print("Extremely light Red")
  elif green > 203 and green < 256:
    print("Perfect light red")

elif red < 255 and green == blue == 0:
  if red > 204:
    print("Slightly Dark Red")
  elif red > 153 and red < 205:
    print("Dark Red")
  elif red > 102 and red < 154:
    print("Medium Dark Red")
  elif red > 51 and red < 103:
    print("Very Dark Red")
  elif red > 0 and red < 52:
    print("Extremely Dark Red")

elif red == blue and green == 255:
  if red == 0 and blue == 0:
    print("Perfect Green")
  elif red > 0 and red < 51:
    print("Bright Green")
  elif red > 50 and red < 102:
    print("Light Green")
  elif red > 101 and red < 153:
    print("Very Light Green")
  elif red > 152 and red < 204:
    print("Extremely light Green")
  elif red > 203 and red < 256:
    print("Perfect light Green")

elif green < 255 and blue == red == 0:
  if green > 204:
    print("Slightly Dark Green")
  elif green > 153 and green < 205:
    print("Dark Green")
  elif green > 102 and green < 154:
    print("Medium Dark Green")
  elif green > 51 and green < 103:
    print("Very Dark Green")
  elif green > 0 and green < 52:
    print("Extremely Dark Green")

elif green == blue and blue == 255:
  if red == 0 and green == 0:
    print("Perfect Blue")
  elif red > 0 and red < 51:
    print("Bright Blue")
  elif red > 50 and red < 102:
    print("Light Blue")
  elif red > 101 and red < 153:
    print("Very Light Blue")
  elif red > 152 and red < 204:
    print("Extremely light Blue")
  elif red > 203 and red < 256:
    print("Perfect light Blue")

elif blue < 255 and green == red == 0:
  if blue > 204:
    print("Slightly Dark Blue")
  elif blue > 153 and blue < 205:
    print("Dark Blue")
  elif blue > 102 and blue < 154:
    print("Medium Dark Blue")
  elif blue > 51 and blue < 103:
    print("Very Dark Blue")
  elif blue > 0 and blue < 52:
    print("Extremely Dark Blue")

if red > green > blue:
  print("Orange")
if red == green > blue:
  print("Yellow")
if blue > red > green:
  print("Purple")
if green>red>blue:
  print("Lime")
if blue==green>red:
  print("Teal")
if green>blue>red:
  print("Blue Green")
if blue>green>red:
  print("Sky Blue")
if red==blue>green:
  print("Pink")
if red>blue>green:
  print("Rose")
# Out:
# Enter R value for your colour:
# 255
# Enter G value for your colour:
# 254
# Enter B value for your colour:
# 255
# Pink
