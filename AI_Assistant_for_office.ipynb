# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharv26j13/2/blob/main/AI_Assistant_for_office.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import smtplib
from email.message import EmailMessage

sender_email = "temporaryatharv@gmail.com"
sender_password = "bfpr jgxi jmhx esnf"
recipient_email = "ankit.one@gmail.com"

msg = EmailMessage()
msg["Subject"] = "Test"
msg["From"] = sender_email
msg["To"] = recipient_email
msg.set_content("HI!")

try:
    with smtplib.SMTP_SSL("smtp.gmail.com", 465) as server:
        server.login(sender_email, sender_password)
        server.send_message(msg)
    print("Email sent successfully!")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Email sent successfully!
