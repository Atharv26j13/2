# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharv26j13/2/blob/main/21b_11_5_26_Customer_Service.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello. Welcome to Temu customer service.")
a = (input("What is the name of the product you have purchased?: "))

def tree1():
  x = int(input("What is the issue with the product:\n 1.Defective\n 2.Broken on delivery\n 3.Missing parts\n"))
  if x == 1:
    print("Please describe the issue with the product")
    (input(":"))
    print("An employee is coming to pick up the product in 2-3 days.\nWould you like to replace the product?(Y/N):")
    x = input("")
    if x == "Y":
      print("The employee will bring a fresh product for you.")
    else:
      print("Thank you for your feedback.")
    print("Your complaint has been forwarded.")
  elif x == 2:
    print("Please give product number on package")
    (input(":"))
    print("An employee is coming to pick up the product in 2-3 days.\nWould you like to replace the product?(Y/N):")
    x = input("")
    if x == "Y":
      print("The employee will bring a fresh product for you.")
    else:
      print("Thank you for your feedback.")
    print("Your complaint has been forwarded.")
  elif x == 3:
    print("Please write which parts are missing")
    (input(":"))
    print("Would you like an employee to come to deliver remaining parts or Would you like to replace the product?(1 or 2):")
    x = int(input(""))
    if x == "2":
      print("The employee will bring a fresh product for you.")
    elif x == "1":
      print("The employee will deliver the remaining parts.")
    else:
      print("ERROR please write 1 or 2\nThank you for your feedback.")
    print("Your complaint has been forwarded.")

def tree2():
  x = int(input("How many stars would you rate the product?(1-5)"))
  if x == 1:
    input("We are so sorry for the experience.\nPlease tell us what problems you faced with the product:")
  elif x == 2:
    input("We are sorry for the troubles.\nPlease tell us what problems you faced with the product:")
  elif x == 3:
    input("We are sorry for any problems.\nPlease share your experience with others:")
  elif x == 4:
    input("Please share about your experience with others:")
  elif x == 5:
    input("We hope you had a nice experience with the product.\nPlease write a few lines describing it:")
  print("Thank you for your feedback")

def start():
  x = int(input(" Enter 1 to raise a complaint\n Enter 2 to write a review\n"))
  if x == 1:
    tree1()
  elif x == 2:
    tree2()
  else:
    print("ERROR, Please enter 1 or 2")
    start()

start()
# Out:
# Hello. Welcome to Temu customer service.
# What is the name of the product you have purchased?: Cow Dung Cake
#  Enter 1 to raise a complaint
#  Enter 2 to write a review
# 2
# How many stars would you rate the product?(1-5)1
# We are so sorry for the experience.
# Please tell us what problems you faced with the product:It tastes terrible!
# Thank you for your feedback
